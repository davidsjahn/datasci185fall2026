# %% [markdown]
# # <span style="color:darkblue"> Lecture 3: Type conversion, Boolean variables and basic logical operators </span>

# %% [markdown]
# <font size="5">
#
# In the previous class we:
# - Introduced types, variables, and lists

# %% [markdown]
# <font size="5">
#
# In this class we will:
#
# - Convert between different types
# - Introduce a new type of object, **boolean** objects
# - Test different categories of expressions with text and numbers

# %%
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## <span style="color:darkblue"> I. Converting between types </span>
#
# <font size="4">
#
# Python gives us built-in functions to convert values deliberately: `str()` turns a value into text, while `int()` and `float()` turn text (or another number) into a number.

# %%
# Three conversion functions:

count_as_text   = str(42)        # the string "42"
price_as_number = float("3.99")  # the float 3.99
year_as_number  = int("2024")    # the integer 2024

print(count_as_text,   type(count_as_text))
print(price_as_number, type(price_as_number))
print(year_as_number,  type(year_as_number))
# Out:
# 42 <class 'str'>
# 3.99 <class 'float'>
# 2024 <class 'int'>

# %%
# WHY THIS MATTERS: arithmetic on strings is not what you expect.

a = "10"
b = "2"

print(a + b)            # "102"  <-- "+" CONCATENATES strings, it does not add
print(int(a) + int(b))  # 12     <-- convert first, then add
# Out:
# 102
# 12

# %% [markdown]
# <font size = "4">
#
# What if we want to add the numbers correctly, but want the final answer stored as a string?

# %%
c = int(a) + int(b) 

c = str(c) # convert integer to string, and overwrite the value

print(c)
print(type(c))
# Out:
# 12
# <class 'str'>

# %% [markdown]
# <font size = "4">
#
# We can break the code up into fine-grained steps. This makes all the necessary computations explicit:

# %%
int_a = int(a) # convert the value of a to an integer
int_b = int(b) # convert the value of b to an integer
int_c = int_a + int_b # add them up
c = str(int_c) # convert the integer answer to a string
print(c)
print(type(c))
# Out:
# 12
# <class 'str'>

# %% [markdown]
# <font size = "4">
#
# Once you get more comfortable with programming, you can combine multiple commands into a single line:

# %%
# The next line is equivalent to the first 4 lines of code in the previous cell
c = str( int(a) + int(b) )
print(c)
print(type(c))
# Out:
# 12
# <class 'str'>

# %% [markdown]
# <font size = "4">
#
# Sometimes the behavior of commands can be different when numbers are represented by strings vs. represented by integers or floats:

# %%
# Month numbers input as strings
months_as_text = ["11", "12", "1", "2"]
sales          = [100, 250, 80, 300]

# Arranges the data in the same order as typed:
plt.bar(x = months_as_text, height = sales)
plt.title("x-values stored as strings")
plt.xlabel("month number (stored as text)")
plt.ylabel("sales")
plt.show()

# %%
months_as_numbers = [11, 12, 1, 2]

plt.bar(x = months_as_numbers, height = sales)
plt.title("x-values stored as integers")
plt.xlabel("month number")
plt.ylabel("sales")
plt.show()

# %% [markdown]
# ## <span style="color:darkblue"> II. Boolean objects </span>
#
# ### Out of the many built-in objects in Python, two of them are of "Boolean" type. These are the objects ``True`` and ``False``

# %%
print(type( True ))
# Out:
# <class 'bool'>

# %%
print(type(False))
# Out:
# <class 'bool'>

# %% [markdown]
# ### These should not be confused with the strings "True" and "False"

# %%
print(type(True)) # Boolean object
print(type("True")) # String
# Out:
# <class 'bool'>
# <class 'str'>

# %%
print(type(False)) # Boolean object
print(type("False")) # String
# Out:
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# ### What is a Boolean object? It is just an object that can take one of two possible values. In this case, True and False

# %% [markdown]
# ## <span style="color:darkblue"> III. Comparison operators </span>
#
# - ### One of the most common ways Boolean objects show up is in the use of **comparison operators**.
# - ### These are operators used to compare two values, and return either ``True`` or ``False``.
# - ### There are six basic comparison operators. The first four are:
#     - #### ``>`` - Greater than
#     - #### ``<`` - Less than
#     - #### ``>=`` - Greater than or equal to
#     - #### ``<=`` - Less than or equal to

# %%
# Test if one number is greater than the other
print(5 > 3)

print(3 > 9)

print(4 + 3 > 6)
# Out:
# True
# False
# True

# %%
# Test if one number is less than the other
print(0 < -2.5)

print(1 < 1.01)

print(30/10 < 1)
# Out:
# False
# True
# False

# %%
# Test if one number is greater that or equal to the other
print(10 >= 1)

print(8 >= 50)

print(2**3 >= 10)
# Out:
# True
# False
# False

# %% [markdown]
# <font size = "4">
#
# **Side note:** You can compare other things besides numbers. This next cell prints `True`, because "Nathan" comes before "Peter" when sorted alphabetically.

# %%
print("Nathan" < "Peter")
# Out:
# True

# %% [markdown]
# <font size = "4">
#
# Back to comparing numbers...

# %%
# Greater than OR equal to!
print(5 > 5) # this is false
print(5 >= 5) # this is true, since 5 equals 5
# Out:
# False
# True

# %%
# Test if one number is less than or equal to the other
print(10 <= 1)

print(8 <= 50)

print(2**3 <= 8)
# Out:
# False
# True
# True

# %% [markdown]
# #### Two more basic comparison operators
# - #### ``==`` - Equal
# - #### ``!=`` - Not equal
#
# #### **Warning**: Do not confuse the assignment operator ``=`` with the comparison operator that tests for equality ``==``

# %%
# Does 5*3 equal 15? (Yes)
print(5*3 == 15)

# Does 3 - 2 equal 7? (No)
print(3 - 2 == 7)
# Out:
# True
# False

# %%
# Is 5*3 + 1 different from 20? (yes)
print(5*3 + 1 != 20)

# Is 10/5 different from 2? (no)
print(10/5 != 2)
# Out:
# True
# False

# %% [markdown]
# #### In most cases, we use a comparison operator with one or more variables

# %%
x = math.sin(4*math.pi/3)
print(x)
print(x > 0)
# Out:
# -0.8660254037844384
# False

# %%
# are these the side lenths of a right triangle?
a = 3
b = 4
c = 5

# How should we test this?


# If these really are the sides of a right triangle, 
# then this should print "True"
print(a**2 + b**2 == c**2)
# Out:
# True

# %% [markdown]
# ### **Pop quiz**: what will print?

# %%
x = 0.1 + 0.1 + 0.1
y = 0.3

print(x == y)
# Out:
# False

# %% [markdown]
# <font size = "4">
#
# This is surprising behavior! Here's an explanation:
#
# - Us humans usually use base-ten (decimal) numbers.
#
# - Floating point numbers in Python use base-two (binary) numbers.
#
# - In base-ten, the number "0.1" denotes the fraction $\frac{1}{10}$
#
# - But in base-two, $\frac{1}{10} = \left(0.0001100110011...\right)_2$ where the pattern $0011$ repeats infinitely.
#
# - Computers have finite memory, so the infinitely repeating binary representation must be rounded. We're only adding up *approximations* to $\frac{1}{10}$
#
# **Lesson:** NEVER test two floating point numbers for equality (integers are o.k. though)

# %% [markdown]
# <font size = "4">
#
# Instead, test if the absolute value of their difference is small. What "small" means is context dependent, but somewhere around $10^{-13}$ is usually o.k:

# %%
print(abs(x - y) < 1e-13)
# Out:
# True

# %% [markdown]
# ## <span style="color:darkblue"> IV. Strings and Lists </span>
#
# - ##### The "equals to" comparison and "not equals to" comparison extend naturally to strings and lists
# - ##### If every character in a string matches another string **exactly**, then they are equal.
# - ##### If every element in a list matches **every** element in another list, then they are equal. **Order of the elements matters**

# %%
x = "Hello World!"
y = "Hello World !"

print(x == "Hello World!")
print(y == "Hello World!")

print(x != y)

print('ab' == 'ba') # false since order matters
# Out:
# True
# False
# True
# False

# %%
list_1 = ["blue", "red", "green"]
list_2 = ["blue", "red", "green"]
list_3 = ["red", "green", "blue"]
list_4 = ["red", "green", "blue", "violet"]
# ordering matters for list(for now)

print(list_1 == list_2)
print(list_1 == list_3) # False: different ordering
print(list_3 == list_4) # False: different number of elements
print(list_3 != list_4) # True
# Out:
# True
# False
# False
# True

# %% [markdown]
# #### The other comparison operators "<", ">", "<=", and ">=" can also be used for strings and lists. However, the behavior is not obvious. See the exercises for more.

# %% [markdown]
# ## <span style="color:darkblue"> V. The "in" keyword </span>
#
# #### This keyword allows us to test whether
# - #### A character appears in a string
# - #### An object appears in a list
# - #### A number appears in a numpy array

# %%
# The first way to use the "in" command is to check whether a word is contained 
# in a sentence. This can be useful if you're trying to search for patterns

# CASE AND SPELLING SENSITIVE

keyword = "economic"
sentence = "The Federal Reserve makes forecasts about many economic outcomes"

print(keyword in sentence)

keyword = "bank"
print(keyword in sentence)

search_word = "Federal" 
print(search_word in sentence)

important_word = "federal"
print(important_word in sentence)
# Out:
# True
# False
# True
# False

# %%
# Use the condition "in" to test whether a word is part of a list
# when the right-hand size is a list "word in list" will search for an exact match

# could use find for lists as well

current_month  = "September"

list_summer_months = ["June","July","August"]

print(current_month in list_summer_months)
print('June' in list_summer_months)
#single quotes double quotes do not mattter, a string is a string
# Out:
# False
# True

# %%
# Use the keyword "in" to see if a number is in a list
# (Later we will see that "in" also works for numpy arrays)

s = [1.0, 3.0, -17, 12]
print(1 in s)
print(type(int(1)) == type(s[1]))
# type matters
# Out:
# True
# False

# %% [markdown]
# ##  <span style="color:darkblue"> VI. Logical Operators </span>
#
# - #### The four logical operators are "not", "and", "or", "^" (this last one is exclusive or)

# %%
p = True
q = False

print(not p)
print(not q)
# it returns the opposite of the value/variable u put in
# Out:
# False
# True

# %%
age  = 22

# True or false? This person can vote in the U.S.

# 1st way to test it:
print(age >= 18)
# Out:
# True

# %%
age  = 22

# True or false? This person can vote in the U.S.

# Do the same test using the "not" keyword

print(not (age < 18))
# Out:
# True

# %%
p = True
q = False
a = True
b = False

print(p and a)
print(p and b)
print(q and a)
print(q and b)
# Out:
# True
# False
# False
# False

# %%
price = 24.5

# True or false? The price is greater than 10 dollars 
# and less than or equal to 20 dollars.

print(price > 10 and price <= 20)
# false since only one is true inside the and thing
# Out:
# False

# %%
# can assign Boolean objects to variables

price = 24.5

statement_1 = price > 10
statement_2 = price <= 20

print(statement_1)
print(statement_2)
print(statement_1 and statement_2) # since one is true one is false, the conjunction is false
# Out:
# True
# False
# False

# %% [markdown]
# <font size = "4">
#
# This also works:

# %%
print(10 < price <= 20) # is this thing between two values?
# Out:
# False

# %% [markdown]
# #### **Both** statements must be true for [statement_1] and [statement_2] to be true
#
# #### To test if **at least** one statment is true, use the "or" operator
#
#
# <font size = "4">
#
# The standard "or" is **inclusive or**

# %%
# incluseive or -> if one is true or both are true, then true
# think of demorgans law

p = True
q = False
a = True
b = False

print(p or a)
print(p or b) # in an 'or' u just need one to be true
print(q or a)
print(q or b)
# Out:
# True
# True
# True
# False

# %%
st_1 = 5 > 3
st_2 = 1 >= 2000

print(st_1 or st_2)
print()

st_3 = 9 < 19
st_4 = 0 < 1
print(st_3 or st_4)
print()

st_5 = -1 >= 10
st_6 = 12 > 13
print(st_5 or st_6)
print()
# Out:
# True
#
# True
#
# False

# %% [markdown]
# #### To test if **exactly** one statment is true, use the "^" operator
#
# <font size = "4">
#
# This is **exclusive or**

# %%
p = True
q = False
a = True
b = False

print(p ^ a) # false since both statements are true. we only want one
print(p ^ b)
print(q ^ a)
print(q ^ b)
# Out:
# False
# True
# True
# False

# %% [markdown]
# #### While not necessary, can separate statements with parentheses for readibility

# %%
x = 13
y = -5
z = False

P = (x > y) and (not z)
print(P)

Q = (x == 5) or (y > 10)
print(Q)

# %% [markdown]
# <font size = "4">

# %% [markdown]
# <font size = "4">
#
# **Warning:** Try to avoid ambiguous chains of conditionals

# %%
age = 21
has_exception = "False"
isolated_room = "False"

statement_1 = age > 18 or has_exception and isolated_room
statement_2 = (age > 18 or has_exception) and isolated_room 
# u have to use parenthesis to specify things

print(statement_1)
print(statement_2)
# Out:
# True
# False
