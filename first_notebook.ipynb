# %% [markdown]
# This is my first Jupyter notebook!
#
# # Big Text
#
# ## Slightly Bigger Text
#
# ###### Small Text

# %% [markdown]
# <font size = "20">
# 20 sized font
#
# <font size = "15" color = "red">
# 15 sized red font

# %%
print("My Name is David Ahn")
